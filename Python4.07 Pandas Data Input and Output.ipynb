# %% [markdown]
# ***
# # 4.07 Pandas Data Input and Output
# - Pandas Documentation: https://pandas.pydata.org/
# ***
# ### Python 4.01. Series
# ### Python 4.02. Pandas DataFrame, Selection, and Indexing
# ### Python 4.03. Configuring Options, Data Type Conversion, Working with strings and dates, Missing Data
# ### Python 4.04. Groupby, Categorizing, and Labeling Data
# ### Python 4.05. Merging,Joining,and Concatenating
# ### Python 4.06. Pipe, Apply, Applymap, Map, Pivot Table, and Cotingency Table
# ### Python 4.07. Data Input and Output
# ### Python 4.08. Data Visualization
# ### Python 4.09. Exploratory Data Analysis and Beyond
# ### Python 4.10. Breakout Group Exercise and Solution
# ***

# %% [markdown]
# # Data Input and Output
#
# This notebook is the reference code for getting input and output, pandas can read a variety of file types using its pd.read_ methods. Let's take a look at the most common data types.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## CSV
#
# ### CSV Input

# %%
import pandas as pd
# Set up a path to data folder
import os
os.chdir(r'C:\Users\yumei\CSP Workshop 2023\Data')
os.getcwd()
# Out:
# 'C:\\Users\\yumei\\CSP Workshop 2023\\Data'

# %%
# %pwd
# Out:
# 'C:\\Users\\yumei\\CSP Workshop 2023\\Data'

# %%
pd.read_csv('titanic_test.csv').head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# Import file from the data folder
df = pd.read_csv('AutoCollision.csv',delimiter = ',' , encoding = 'unicode_escape')
df.head()
# Out:
#    AgeGroup  VehicleUse  ClaimSeverity  ClaimCount
# 0  17 to 20    Pleasure         250.48          21
# 1  17 to 20  DriveShort         274.78          40
# 2  17 to 20   DriveLong         244.52          23
# 3  17 to 20    Business         797.80           5
# 4  21 to 24    Pleasure         213.71          63

# %%
# Import file from the data folder
df = pd.read_csv('AutoCollision.csv', delimiter = ',' , encoding = 'unicode_escape')
df.head()
# Out:
#    AgeGroup  VehicleUse  ClaimSeverity  ClaimCount
# 0  17 to 20    Pleasure         250.48          21
# 1  17 to 20  DriveShort         274.78          40
# 2  17 to 20   DriveLong         244.52          23
# 3  17 to 20    Business         797.80           5
# 4  21 to 24    Pleasure         213.71          63

# %% [markdown]
# ### CSV Output

# %%
df.to_csv('example',index=False)

# %% [markdown]
# ## Excel
# Pandas can read and write excel files, keep in mind, this only imports data. Not formulas or images, having images or macros may cause this read_excel method to crash.

# %% [markdown]
# ### Excel Input

# %%
df=pd.read_excel('Excel_SampleInput.xlsx',sheet_name='Sheetnew')
df
# Out:
#    Unnamed: 0.1  Unnamed: 0  0   1   2   3
# 0             0           0  1   5   6   7
# 1             1           1  2   9  10  11
# 2             2           2  3  13  14  15

# %% [markdown]
# ### Excel Output

# %%
df.to_excel('Excel_SampleOutput.xlsx',sheet_name='Sheetnew')

# %% [markdown]
# ## HTML
#
# You may need to install htmllib5,lxml, and BeautifulSoup4. In your terminal/command prompt run:
#
#     conda install lxml
#     conda install html5lib
#     conda install BeautifulSoup4
#
# Then restart Jupyter Notebook.
# (or use pip install if you aren't using the Anaconda Distribution)
#
# Pandas can read table tabs off of html. For example:

# %% [markdown]
# ### HTML Input
#
# Pandas read_html function will read tables off of a webpage and return a list of DataFrame objects:

# %%
import pandas as pd
df = pd.read_html(r'https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list')
df
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# C:\ProgramData\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1278         """Send a complete request to the server."""
# -> 1279         self._send_request(method, url, body, headers, encode_chunked)
#    1280
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1324             body = _encode(body, 'body')
# -> 1325         self.endheaders(body, encode_chunked=encode_chunked)
#    1326
#
# ...

# %%
df[0].head()
# Out:
# 0    1
# 1    2
# 2    3
# Name: 0, dtype: int64

# %%
df[0].shape
# Out:
# (3,)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Exercise: Input AutoCollision.csv

# %%
import os
# %pwd
# Out:
# 'C:\\Users\\yumei\\CSP Workshop 2023\\Data'

# %%
wcdf=pd.read_csv("WCClaim.csv")
wcdf
# Out:
#     ClaimType                 InjuryType LineCode LineType  \
# 0          IN  05 - Temporary Total/Part       XW       WC
# 1          IN  05 - Temporary Total/Part       WC       WC
# 2          IN  04 - Unscheduled Permanen       WC       WC
# 3          IN  03 - Major Permanent Part       WC       WC
# 4          IN  05 - Temporary Total/Part       WC       WC
# ..        ...                        ...      ...      ...
# 308        IN  05 - Temporary Total/Part       WC       WC
# 309        IN  05 - Temporary Total/Part       WC       WC
# 310        IN  05 - Temporary Total/Part       WC       WC
# 311        IN  05 - Temporary Total/Part       WC       WC
# 312        IN  05 - Temporary Total/Part       WC       WC
#
#     StateofJurisdiction  TotalDaysClaimOpen ClaimStatus ClaimSubstatus  \
# 0                    OK                1890           O       Accepted
# 1                    CT                1312           O       Accepted
# ...

# %%
# check data dimentions
wcdf.shape
# Out:
# (313, 22)

# %%
wcdf.head()
# Out:
#   ClaimType                 InjuryType LineCode LineType StateofJurisdiction  \
# 0        IN  05 - Temporary Total/Part       XW       WC                  OK
# 1        IN  05 - Temporary Total/Part       WC       WC                  CT
# 2        IN  04 - Unscheduled Permanen       WC       WC                  NV
# 3        IN  03 - Major Permanent Part       WC       WC                  CA
# 4        IN  05 - Temporary Total/Part       WC       WC                  NC
#
#    TotalDaysClaimOpen ClaimStatus ClaimSubstatus  BodyPartDescription  \
# 0                1890           O       Accepted  Multiple Body Parts
# 1                1312           O       Accepted  Multiple Body Parts
# 2                 367           O       Accepted  Multiple Body Parts
# 3                2977           O       Accepted                 Knee
# 4                1422           O       Accepted                 Knee
#
#   DateReported  ... RTWFullDuty PreInjuryAWW NetTotalIncurred  \
# ...

# %%
wcdf.tail(2)
# Out:
#     ClaimType                 InjuryType LineCode LineType  \
# 311        IN  05 - Temporary Total/Part       WC       WC
# 312        IN  05 - Temporary Total/Part       WC       WC
#
#     StateofJurisdiction  TotalDaysClaimOpen ClaimStatus ClaimSubstatus  \
# 311                  PA                 319           O       Accepted
# 312                  ME                 178           O       Accepted
#
#     BodyPartDescription DateReported  ... RTWFullDuty PreInjuryAWW  \
# 311                Foot    1/14/2013  ...   1/22/2013       1100.0
# 312                 Hip     6/4/2013  ...    6/5/2013          1.0
#
#     NetTotalIncurred  DateofTermination  ClaimIncurredIndLoss  \
# 311          3910.08                NaN                131.00
# 312          3832.11                NaN                 34.27
#
#      ClaimIncurredMedical  NumberofReserveChanges  ResultNatureDescription  \
# 311               3210.43                       5                   Sprain
# ...

# %%
# review data columns
wcdf.columns
# Out:
# Index(['ClaimType', 'InjuryType', 'LineCode', 'LineType',
#        'StateofJurisdiction', 'TotalDaysClaimOpen', 'ClaimStatus',
#        'ClaimSubstatus', 'BodyPartDescription', 'DateReported', 'DateLoss',
#        'SurgeryFlag', 'RTWFullDuty', 'PreInjuryAWW', 'NetTotalIncurred',
#        'DateofTermination', 'ClaimIncurredIndLoss', 'ClaimIncurredMedical',
#        'NumberofReserveChanges', 'ResultNatureDescription', 'CauseDescription',
#        'NetTotalPaid'],
#       dtype='object')

# %%
# review data type
wcdf.dtypes
# Out:
# ClaimType                   object
# InjuryType                  object
# LineCode                    object
# LineType                    object
# StateofJurisdiction         object
# TotalDaysClaimOpen           int64
# ClaimStatus                 object
# ClaimSubstatus              object
# BodyPartDescription         object
# DateReported                object
# DateLoss                    object
# SurgeryFlag                 object
# RTWFullDuty                 object
# PreInjuryAWW               float64
# NetTotalIncurred           float64
# DateofTermination          float64
# ClaimIncurredIndLoss       float64
# ClaimIncurredMedical       float64
# NumberofReserveChanges       int64
# ResultNatureDescription     object
# CauseDescription            object
# NetTotalPaid               float64
# dtype: object

# %%
# subsetting data with loc & iloc
wcdf.loc[3:5]
# Out:
#   ClaimType                 InjuryType LineCode LineType StateofJurisdiction  \
# 3        IN  03 - Major Permanent Part       WC       WC                  CA
# 4        IN  05 - Temporary Total/Part       WC       WC                  NC
# 5        IN  04 - Unscheduled Permanen       WC       WC                  IL
#
#    TotalDaysClaimOpen ClaimStatus ClaimSubstatus BodyPartDescription  \
# 3                2977           O       Accepted                Knee
# 4                1422           O       Accepted                Knee
# 5                 733           O       Accepted    Back (All Other)
#
#   DateReported  ... RTWFullDuty PreInjuryAWW NetTotalIncurred  \
# 3    9/22/2005  ...         NaN      1389.85        455298.54
# 4     1/7/2010  ...         NaN         1.00        523300.72
# 5   11/28/2011  ...         NaN      1087.93        572946.37
#
#    DateofTermination  ClaimIncurredIndLoss  ClaimIncurredMedical  \
# ...

# %%
wcdf.loc[3:5,['InjuryType','LineCode','LineType','StateofJurisdiction','TotalDaysClaimOpen']]
# Out:
#                   InjuryType LineCode LineType StateofJurisdiction  \
# 3  03 - Major Permanent Part       WC       WC                  CA
# 4  05 - Temporary Total/Part       WC       WC                  NC
# 5  04 - Unscheduled Permanen       WC       WC                  IL
#
#    TotalDaysClaimOpen
# 3                2977
# 4                1422
# 5                 733

# %%
wcdf.iloc[0:5,[0,1,3]]
# Out:
#   ClaimType                 InjuryType LineType
# 0        IN  05 - Temporary Total/Part       WC
# 1        IN  05 - Temporary Total/Part       WC
# 2        IN  04 - Unscheduled Permanen       WC
# 3        IN  03 - Major Permanent Part       WC
# 4        IN  05 - Temporary Total/Part       WC

# %% [markdown]
# ### There is a number of pandas commands to read other data formats:
#
# - pd.read_stata('myfile.dta')
#
# - pd.read_sas('myfile.sas7bdat')
#
# - pd.read_hdf('myfile.h5','df')
#
# - pd.read_pickle('sub.pkl'): creating a pickle file is much faster than excel or csv files when the file size is large
#
# - https://pandas.pydata.org/docs/reference/api/pandas.read_json.html
#
# - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_pickle.html

# %% [markdown]
# #### Note: The course materials are developed mainly based on personal experience and contributions from the Python learning community
# Referred Books:
# - Learning Python, 5th Edition by Mark Lutz
# - Python Data Science Handbook, Jake, VanderPlas
# - Python for Data Analysis, Wes McKinney
#
# Copyright ©2023 Mei Najim. All rights reserved.
